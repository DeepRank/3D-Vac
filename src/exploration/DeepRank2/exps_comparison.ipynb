# %%
import pandas as pd
from datetime import datetime
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import os
from itertools import cycle
import numpy as np
from sklearn.metrics import (
    roc_curve,
    precision_recall_curve,
    auc,
    average_precision_score,
    f1_score,
    matthews_corrcoef)

# %%
######## Modify here
project_folder = '/projects/0/einf2380'
protein_class = 'I'
exp_path = f'{project_folder}/data/pMHC{protein_class}/trained_models/deeprank2/experiments/'
exp_ids = [
    'exp_100k_std_transf_bs64_naivegnn1_wloss_0',
    'exp_100k_std_transf_bs64_naivegnn1_wloss_cl_allele_0',
    'exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1'
    ]
comparison_id = 'check_during_runs'

# %%
exp_type = 'All configurations with the best model'
exp_log = pd.read_excel(exp_path + '_experiments_log.xlsx', index_col='exp_id')
exp_log.head()
# Out:
#                                                                                          exp_fullname  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1  exp_100k_std_transf_bs64_naivegnn1_wloss_n_run...
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...  exp_100k_std_transf_bs64_naivegnn1_wloss_all_d...
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...  exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pe...
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...  exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pe...
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...  exp_100k_std_transf_bs64_naivegnn1_wloss_wdeca...
#
#                                                                                              exp_path  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1  /projects/0/einf2380/data/pMHCI/trained_models...
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...  /projects/0/einf2380/data/pMHCI/trained_models...
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...  /projects/0/einf2380/data/pMHCI/trained_models...
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...  /projects/0/einf2380/data/pMHCI/trained_models...
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...  /projects/0/einf2380/data/pMHCI/trained_models...
#
#                                                               start_time  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1  30/May/2024_15:32:07
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...  06/Oct/2023_17:19:14
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...  23/Aug/2023_12:24:43
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...  23/Aug/2023_12:22:00
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...  09/Aug/2023_10:27:46
#
#                                                                 end_time  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1  30/May/2024_19:18:53
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...  06/Oct/2023_22:28:17
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...  23/Aug/2023_18:42:33
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...  23/Aug/2023_18:40:56
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...  09/Aug/2023_18:31:10
#
#                                                                                       input_data_path  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1  ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...  ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...  ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...  ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...  ['/projects/0/einf2380/data/pMHCI/features_out...
#
#                                                    protein_class target_data  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1             I          BA
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...             I          BA
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...             I          BA
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...             I          BA
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...             I          BA
#
#                                                    resolution     task  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1    residue  classif
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...    residue  classif
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...    residue  classif
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...    residue  classif
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...    residue  classif
#
#                                                    node_features  ...  \
# exp_id                                                            ...
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1           all  ...
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...           all  ...
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...           all  ...
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...           all  ...
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...           all  ...
#
#                                                    validation_precision  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1                0.759
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...                  NaN
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...                0.721
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...                0.804
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...                0.748
#
#                                                    testing_precision  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1             0.738
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...               NaN
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...             0.690
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...             0.749
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...             0.731
#
#                                                    training_recall  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1           0.749
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...             NaN
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...           0.856
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...           0.693
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...           0.756
#
#                                                     validation_recall  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1              0.722
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...                NaN
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...              0.812
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...              0.636
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...              0.741
#
#                                                     testing_recall  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1           0.765
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...             NaN
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...           0.786
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...           0.813
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...           0.727
#
#                                                     training_loss  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1       0.423666
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...       0.438956
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...       0.420715
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...       0.417234
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...       0.469321
#
#                                                     validation_loss  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1         0.473236
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...              NaN
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...         0.465591
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...         0.465967
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...         0.480995
#
#                                                    testing_loss  \
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1     0.495836
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...          NaN
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...     0.513852
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...     0.549702
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...     0.496913
#
#                                                     test_clusters  features
# exp_id
# exp_100k_std_transf_bs64_naivegnn1_wloss_n_run_1_1            NaN       NaN
# exp_100k_std_transf_bs64_naivegnn1_wloss_all_da...            NaN       NaN
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...            [3]       NaN
# exp_100k_std_transf_bs64_naivegnn1_wloss_cl_pep...            [3]       NaN
# exp_100k_std_transf_bs64_naivegnn1_wloss_wdecay...            [3]       NaN
#
# [5 rows x 50 columns]

# %%
######## Definitions used in the plotting
comparisons_path = os.path.join(exp_path, 'comparisons')
comparison_path = os.path.join(comparisons_path, comparison_id)

if not os.path.exists(comparisons_path):
    os.makedirs(comparisons_path)

if not os.path.exists(comparison_path):
    os.makedirs(comparison_path)
else:
    print(f'Folder comparisons/{comparison_id}/ already exists! \
          \nChange comparison_id if you want to save plots for a different comparison.')

def get_single_exp_df(exp_id, exp_log, exp_path):
    exp_fullname = exp_log.loc[exp_id].exp_fullname
    exp_path = os.path.join(exp_path, exp_fullname)
    output_path = os.path.join(exp_path, 'output')
    output_train = pd.read_hdf(os.path.join(output_path, 'output_exporter.hdf5'), key='training')
    output_test = pd.read_hdf(os.path.join(output_path, 'output_exporter.hdf5'), key='testing')
    df = pd.concat([output_train, output_test])
    df.sort_values(by=['epoch'], inplace = True)
    return df

# %%
######## Losses curves
palette = cycle(px.colors.qualitative.Plotly)
fig = go.Figure()

for exp_id in exp_ids:
    df = get_single_exp_df(exp_id, exp_log, exp_path)
    df_grouped = df.groupby(['phase', 'epoch']).mean(numeric_only=True).reset_index()[['phase', 'epoch', 'loss']]
    color = next(palette)
    df_train_plot = df_grouped[(df_grouped.phase =='training') & (df_grouped.epoch > 0)]
    df_valid_plot = df_grouped[(df_grouped.phase =='validation') & (df_grouped.epoch > 0)]

    fig.add_trace(go.Scatter(
        x=df_train_plot.epoch,
        y=df_train_plot.loss,
        mode = 'lines+markers',
        line=dict(color=color),
        name='training',
        legendgroup=exp_id,
        legendgrouptitle_text=exp_id))
    fig.add_trace(go.Scatter(
        x=df_valid_plot.epoch,
        y=df_valid_plot.loss,
        mode = 'lines+markers',
        line=dict(color=color, dash='dot'),
        name='validation',
        legendgroup=exp_id,
        legendgrouptitle_text=exp_id))
    
    epoch = exp_log.loc[exp_id].saved_epoch
    fig.add_trace(go.Scatter(
        x=[epoch],
        y=[exp_log.loc[exp_id].training_loss],
        mode = 'markers',
        marker_symbol = 'star',
        marker_color = 'firebrick',
        marker_size = 15,
        name = f'epoch {epoch}',
        legendgroup=exp_id,
        showlegend = False))

fig.update_layout(
    xaxis_title='Epoch #',
    yaxis_title='Loss',
    width=800, height=500,
    title='Loss vs epochs',
    title_x=0.5,
    margin=go.layout.Margin(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4),
    legend=dict(
        yanchor="top",
        xanchor="right",
        x=0.99
        )
)
fig.write_html(os.path.join(comparison_path, 'losses.html'))

# %%
######## AUC and AUCPR curves
palette = cycle(px.colors.qualitative.Plotly)
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles = ['ROC Curves (AUC)', 'PR Curves (AUCPR)'],
    horizontal_spacing = 0.05)

for exp_id in exp_ids:
    epoch = exp_log.loc[exp_id].saved_epoch
    df = get_single_exp_df(exp_id, exp_log, exp_path)
    df_plot = df[(df.epoch == epoch) & (df.phase == 'testing')]
    y_true = df_plot.target
    y_score = np.array(df_plot.output.values.tolist())[:, 1]
    color = next(palette)

    df_plot_phase = df_plot
    y_true = df_plot_phase.target
    y_score = np.array(df_plot_phase.output.values.tolist())[:, 1]

    fpr_roc, tpr_roc, thr_roc = roc_curve(y_true, y_score)
    pr_pr, rec_pr, thr_pr = precision_recall_curve(y_true, y_score)

    name_roc = f'AUC={auc(fpr_roc, tpr_roc):.4f}'
    name_pr = f'AUCPR={average_precision_score(y_true, y_score):.4f}'

    fig.add_trace(go.Scatter(
        x=fpr_roc,
        y=tpr_roc,
        name=name_roc,
        line=dict(color=color),
        legendgroup=exp_id,
        legendgrouptitle_text=exp_id),
        row=1,
        col=1)
    fig.add_trace(go.Scatter(
        x=rec_pr,
        y=pr_pr,
        name=name_pr,
        line=dict(color=color),
        legendgroup=exp_id,
        legendgrouptitle_text=exp_id),
        row=1,
        col=2)

fig.add_shape(
    type='line', line=dict(dash='dash'),
    x0=0, x1=1, y0=0, y1=1,
    row = 1, col = 1
)
fig.add_shape(
    type='line', line=dict(dash='dash'),
    x0=0, x1=1, y0=1, y1=0,
    row = 1, col = 2 
)
fig.update_layout(
    width=900, height=400,
    margin=go.layout.Margin(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    legend=dict(
        yanchor="top",
        y=1.05,
        xanchor="left",
        x=0.97
        ))
fig.update_xaxes(title_text="FPR", constrain='domain', scaleratio = 1, row=1, col=1)
fig.update_yaxes(title_text="TPR (Recall)", constrain='domain', scaleanchor = "x", scaleratio = 1, row=1, col=1)
fig.update_xaxes(title_text="Recall", constrain='domain', scaleanchor = "y", scaleratio = 1, row=1, col=2)
fig.update_yaxes(title_text="Precision", constrain='domain', scaleratio = 1, row=1, col=2)
fig.update_layout(
    title='AUC and AUCPR curves for testing set',
    title_x=0.5,
    margin={'t': 100})
fig.write_html(os.path.join(comparison_path, 'auc_aucpr_testing.html'))

# %%
fig = go.Figure()
auc_scores = []

for exp_id in exp_ids:
    epoch = exp_log.loc[exp_id].saved_epoch
    df = get_single_exp_df(exp_id, exp_log, exp_path)
    df_plot = df[(df.epoch == epoch) & (df.phase == 'testing')]
    y_true = df_plot.target
    y_score = np.array(df_plot.output.values.tolist())[:, 1]
    color = next(palette)

    df_plot_phase = df_plot
    y_true = df_plot_phase.target
    y_score = np.array(df_plot_phase.output.values.tolist())[:, 1]

    fpr_roc, tpr_roc, thr_roc = roc_curve(y_true, y_score)
    pr_pr, rec_pr, thr_pr = precision_recall_curve(y_true, y_score)

    auc_score = auc(fpr_roc, tpr_roc)
    auc_scores.append(auc_score)
    name_roc = f'AUC={auc_score:.4f}'

    fig.add_trace(go.Bar(
        x = ['AUC'],
        y = [auc_score],
        name = name_roc,
        legendgroup = exp_id,
        legendgrouptitle_text = exp_id
    ))

fig.update_yaxes(title_text="Value")
fig.update_layout(
    barmode='group',
    title=f'AUC bars comparison for {exp_type}',
    title_x=0.5,
    width=1100, height=600)
fig.write_html(os.path.join(comparison_path, 'auc_testing_bars.html'))

# %%
######## F1 and MCC bar plots 
palette = cycle(px.colors.qualitative.Plotly)
fig = go.Figure()

for exp_id in exp_ids:

    ########### Pick threshold for maximizing MCC on the validation set
    epoch = exp_log.loc[exp_id].saved_epoch
    df = get_single_exp_df(exp_id, exp_log, exp_path)
    df_valid = df[(df.epoch == epoch) & (df.phase == 'validation')]

    y_true = df_valid.target
    y_score = np.array(df_valid.output.values.tolist())[:, 1]

    thrs = np.linspace(0,1,100)
    accuracy = []
    f1 = []
    mcc = []
    for thr in thrs:
        y_pred = (y_score > thr)*1
        f1.append(f1_score(y_true, y_pred))
        mcc.append(matthews_corrcoef(y_true, y_pred))

    thr_df = pd.DataFrame({
        'thr': thrs,
        'f1': f1,
        'mcc': mcc})
    # maximize mcc for this model, using validation set
    mcc_idxmax = thr_df.mcc.idxmax()
    sel_thr = thr_df.loc[mcc_idxmax].thr
    ###############

    # apply selected threshold on the testing set
    df_plot = df[(df.epoch == epoch) & (df.phase == 'testing')]
    y_true = df_plot.target
    y_score = np.array(df_plot.output.values.tolist())[:, 1]
    y_pred = (y_score > sel_thr)*1
    color = next(palette)
    f1 = f1_score(y_true, y_pred)
    mcc = matthews_corrcoef(y_true, y_pred)

    name_f1 = f'F1={f1:.4f}'
    name_mcc = f'MCC={mcc:.4f}'

    fig.add_trace(go.Bar(
        x=['F1', 'MCC'],
        y=[f1, mcc],
        name = name_f1 + ', ' + name_mcc,
        legendgroup=exp_id,
        legendgrouptitle_text=exp_id,
        marker_color = color
    ))

fig.update_yaxes(title_text="Score")
fig.update_layout(
    barmode='group',
    title='F1 and MCC scores for testing set',
    title_x=0.5,
    width=800, height=500)
fig.write_html(os.path.join(comparison_path, 'f1_mcc_thr.5_testing.html'))

# %%
######## Timings
fig = go.Figure()

for exp_id in exp_ids:
    start = exp_log.loc[exp_id].start_time
    end = exp_log.loc[exp_id].end_time
    start_dt = datetime.strptime(start, '%d/%b/%Y_%H:%M:%S')
    end_dt = datetime.strptime(end, '%d/%b/%Y_%H:%M:%S')
    time = end_dt - start_dt

    fig.add_trace(go.Bar(
        x=[exp_id],
        y=[time.seconds],
        name = str(time) + ' hours'
    ))

fig.update_yaxes(title_text="Seconds")
fig.update_layout(
    barmode='group',
    title='Total timings for the experiments',
    title_x=0.5,
    width=600, height=500)
fig.write_html(os.path.join(comparison_path, 'timings.html'))
