# %%
import pandas as pd
from datetime import datetime
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import os
from itertools import cycle
import numpy as np
from sklearn.metrics import (
    roc_curve,
    precision_recall_curve,
    auc,
    average_precision_score,
    f1_score,
    matthews_corrcoef)

# %%
######## Modify here
exp_path = './experiments/'
exp_ids = [
    'exp_100k_final_bs64_seed11_rmpssm0',
    'exp_100k_final_feat_trans_seed11_rmpssm_0']
comparison_id = 'feattrans_experiment'
exp_type = 'shuffle'
exp_log = pd.read_excel(exp_path + '_experiments_log.xlsx', index_col='exp_id')
exp_log.head()
# Out:
#                                                                                     exp_fullname  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0         exp_100k_final_increase1_seed11_rmpssm_0_230530
# exp_100k_final_increase2_ep60_seed11_rmpssm_0  exp_100k_final_increase2_ep60_seed11_rmpssm_0_...
# exp_100k_final_increase2_ep70_seed11_rmpssm_0  exp_100k_final_increase2_ep70_seed11_rmpssm_0_...
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0         exp_100k_final_BN1_seed11_es0.2_rmpssm_0_230530
# exp_100k_final_feat_trans_seed11_rmpssm_0       exp_100k_final_feat_trans_seed11_rmpssm_0_230530
#
#                                                                                         exp_path  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0       ./experiments/exp_100k_final_increase1_seed11_...
# exp_100k_final_increase2_ep60_seed11_rmpssm_0  ./experiments/exp_100k_final_increase2_ep60_se...
# exp_100k_final_increase2_ep70_seed11_rmpssm_0  ./experiments/exp_100k_final_increase2_ep70_se...
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0       ./experiments/exp_100k_final_BN1_seed11_es0.2_...
# exp_100k_final_feat_trans_seed11_rmpssm_0      ./experiments/exp_100k_final_feat_trans_seed11...
#
#                                                          start_time  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0       30/May/2023_17:44:12
# exp_100k_final_increase2_ep60_seed11_rmpssm_0  30/May/2023_17:52:05
# exp_100k_final_increase2_ep70_seed11_rmpssm_0  30/May/2023_17:58:35
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0       30/May/2023_14:04:11
# exp_100k_final_feat_trans_seed11_rmpssm_0      30/May/2023_02:50:52
#
#                                                            end_time  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0       30/May/2023_23:42:56
# exp_100k_final_increase2_ep60_seed11_rmpssm_0  30/May/2023_23:30:17
# exp_100k_final_increase2_ep70_seed11_rmpssm_0  30/May/2023_23:22:30
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0       30/May/2023_17:26:17
# exp_100k_final_feat_trans_seed11_rmpssm_0      30/May/2023_05:29:15
#
#                                                                                  input_data_path  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0       ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_final_increase2_ep60_seed11_rmpssm_0  ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_final_increase2_ep70_seed11_rmpssm_0  ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0       ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_final_feat_trans_seed11_rmpssm_0      ['/projects/0/einf2380/data/pMHCI/features_out...
#
#                                               protein_class target_data  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0                  I          BA
# exp_100k_final_increase2_ep60_seed11_rmpssm_0             I          BA
# exp_100k_final_increase2_ep70_seed11_rmpssm_0             I          BA
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0                  I          BA
# exp_100k_final_feat_trans_seed11_rmpssm_0                 I          BA
#
#                                               resolution     task  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0         residue  classif
# exp_100k_final_increase2_ep60_seed11_rmpssm_0    residue  classif
# exp_100k_final_increase2_ep70_seed11_rmpssm_0    residue  classif
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0         residue  classif
# exp_100k_final_feat_trans_seed11_rmpssm_0        residue  classif
#
#                                               node_features  ...  \
# exp_id                                                       ...
# exp_100k_final_increase1_seed11_rmpssm_0                all  ...
# exp_100k_final_increase2_ep60_seed11_rmpssm_0           all  ...
# exp_100k_final_increase2_ep70_seed11_rmpssm_0           all  ...
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0                all  ...
# exp_100k_final_feat_trans_seed11_rmpssm_0               all  ...
#
#                                               training_accuracy  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0                  0.793
# exp_100k_final_increase2_ep60_seed11_rmpssm_0             0.816
# exp_100k_final_increase2_ep70_seed11_rmpssm_0             0.801
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0                  0.727
# exp_100k_final_feat_trans_seed11_rmpssm_0                 0.792
#
#                                               validation_accuracy  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0                    0.765
# exp_100k_final_increase2_ep60_seed11_rmpssm_0               0.784
# exp_100k_final_increase2_ep70_seed11_rmpssm_0               0.771
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0                    0.720
# exp_100k_final_feat_trans_seed11_rmpssm_0                   0.773
#
#                                               testing_accuracy  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0                 0.771
# exp_100k_final_increase2_ep60_seed11_rmpssm_0            0.784
# exp_100k_final_increase2_ep70_seed11_rmpssm_0            0.782
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0                 0.745
# exp_100k_final_feat_trans_seed11_rmpssm_0                0.777
#
#                                                training_precision  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0                    0.720
# exp_100k_final_increase2_ep60_seed11_rmpssm_0               0.790
# exp_100k_final_increase2_ep70_seed11_rmpssm_0               0.739
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0                    0.635
# exp_100k_final_feat_trans_seed11_rmpssm_0                   0.734
#
#                                                validation_precision  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0                      0.686
# exp_100k_final_increase2_ep60_seed11_rmpssm_0                 0.745
# exp_100k_final_increase2_ep70_seed11_rmpssm_0                 0.703
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0                      0.630
# exp_100k_final_feat_trans_seed11_rmpssm_0                     0.711
#
#                                                testing_precision  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0                   0.702
# exp_100k_final_increase2_ep60_seed11_rmpssm_0              0.759
# exp_100k_final_increase2_ep70_seed11_rmpssm_0              0.736
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0                   0.714
# exp_100k_final_feat_trans_seed11_rmpssm_0                  0.720
#
#                                                training_recall  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0                 0.867
# exp_100k_final_increase2_ep60_seed11_rmpssm_0            0.794
# exp_100k_final_increase2_ep70_seed11_rmpssm_0            0.846
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0                 0.894
# exp_100k_final_feat_trans_seed11_rmpssm_0                0.829
#
#                                               validation_recall  \
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0                  0.857
# exp_100k_final_increase2_ep60_seed11_rmpssm_0             0.776
# exp_100k_final_increase2_ep70_seed11_rmpssm_0             0.832
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0                  0.882
# exp_100k_final_feat_trans_seed11_rmpssm_0                 0.815
#
#                                                testing_recall  test_clusters
# exp_id
# exp_100k_final_increase1_seed11_rmpssm_0                0.836            NaN
# exp_100k_final_increase2_ep60_seed11_rmpssm_0           0.746            NaN
# exp_100k_final_increase2_ep70_seed11_rmpssm_0           0.786            NaN
# exp_100k_final_BN1_seed11_es0.2_rmpssm_0                0.702            NaN
# exp_100k_final_feat_trans_seed11_rmpssm_0               0.806            NaN
#
# [5 rows x 49 columns]

# %%
######## Definitions used in the plotting
comparisons_path = os.path.join(exp_path, 'comparisons')
comparison_path = os.path.join(comparisons_path, comparison_id)

if not os.path.exists(comparisons_path):
    os.makedirs(comparisons_path)

if not os.path.exists(comparison_path):
    os.makedirs(comparison_path)
else:
    print(f'Folder comparisons/{comparison_id}/ already exists! \
          \nChange comparison_id if you want to save plots for a different comparison.')

def get_single_exp_df(exp_id, exp_log, exp_path):
    exp_fullname = exp_log.loc[exp_id].exp_fullname
    exp_path = os.path.join(exp_path, exp_fullname)
    output_path = os.path.join(exp_path, 'output')
    output_train = pd.read_hdf(os.path.join(output_path, 'output_exporter.hdf5'), key='training')
    output_test = pd.read_hdf(os.path.join(output_path, 'output_exporter.hdf5'), key='testing')
    df = pd.concat([output_train, output_test])
    df.sort_values(by=['epoch'], inplace = True)
    return df
# Out:
# Folder comparisons/feattrans_experiment/ already exists!
# Change comparison_id if you want to save plots for a different comparison.

# %%
######## Losses curves
palette = cycle(px.colors.qualitative.Plotly)
fig = go.Figure()

for exp_id in exp_ids:
    df = get_single_exp_df(exp_id, exp_log, exp_path)
    df_grouped = df.groupby(['phase', 'epoch']).mean().reset_index()[['phase', 'epoch', 'loss']]
    color = next(palette)
    df_train_plot = df_grouped[(df_grouped.phase =='training') & (df_grouped.epoch > 0)]
    df_valid_plot = df_grouped[(df_grouped.phase =='validation') & (df_grouped.epoch > 0)]

    fig.add_trace(go.Scatter(
        x=df_train_plot.epoch,
        y=df_train_plot.loss,
        mode = 'lines+markers',
        line=dict(color=color),
        name='training',
        legendgroup=exp_id,
        legendgrouptitle_text=exp_id))
    fig.add_trace(go.Scatter(
        x=df_valid_plot.epoch,
        y=df_valid_plot.loss,
        mode = 'lines+markers',
        line=dict(color=color, dash='dot'),
        name='validation',
        legendgroup=exp_id,
        legendgrouptitle_text=exp_id))
    
    epoch = exp_log.loc[exp_id].saved_epoch
    fig.add_trace(go.Scatter(
        x=[epoch],
        y=[exp_log.loc[exp_id].training_loss],
        mode = 'markers',
        marker_symbol = 'star',
        marker_color = 'firebrick',
        marker_size = 15,
        name = f'epoch {epoch}',
        legendgroup=exp_id,
        showlegend = False))

fig.update_layout(
    xaxis_title='Epoch #',
    yaxis_title='Loss',
    width=800, height=500,
    title='Loss vs epochs',
    title_x=0.5,
    margin=go.layout.Margin(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4),
    legend=dict(
        yanchor="top",
        xanchor="right",
        x=0.99
        )
)
fig.write_html(os.path.join(comparison_path, 'losses.html'))
# Out:
# /scratch-local/cyulin/ipykernel_1927385/3607644268.py:7: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /scratch-local/cyulin/ipykernel_1927385/3607644268.py:7: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
######## AUC and AUCPR curves
palette = cycle(px.colors.qualitative.Plotly)
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles = ['ROC Curves (AUC)', 'PR Curves (AUCPR)'],
    horizontal_spacing = 0.05)

for exp_id in exp_ids:
    df = get_single_exp_df(exp_id, exp_log, exp_path)
    if(exp_id == 'exp_100k_final_bs64_seed11_rmpssm0'):
        df_plot = df[(df.epoch == 0) & (df.phase == 'testing')]
        y_true = df_plot.target
        y_score = np.array(df_plot.output.values.tolist())[:, 1]
        color = next(palette)

        df_plot_phase = df_plot
        y_true = df_plot_phase.target
        y_score = np.array(df_plot_phase.output.values.tolist())[:, 1]
    else:
        df_plot = df[(df.epoch == 25) & (df.phase == 'testing')]
        y_true = df_plot.target
        y_score = np.array(df_plot.output.values.tolist())[:, 1]
        color = next(palette)

        df_plot_phase = df_plot
        y_true = df_plot_phase.target
        y_score = np.array(df_plot_phase.output.values.tolist())[:, 1]
    

    fpr_roc, tpr_roc, thr_roc = roc_curve(y_true, y_score)
    pr_pr, rec_pr, thr_pr = precision_recall_curve(y_true, y_score)

    name_roc = f'AUC={auc(fpr_roc, tpr_roc):.4f}'
    name_pr = f'AUCPR={average_precision_score(y_true, y_score):.4f}'

    fig.add_trace(go.Scatter(
        x=fpr_roc,
        y=tpr_roc,
        name=name_roc,
        line=dict(color=color),
        legendgroup=exp_id,
        legendgrouptitle_text=exp_id),
        row=1,
        col=1)
    fig.add_trace(go.Scatter(
        x=rec_pr,
        y=pr_pr,
        name=name_pr,
        line=dict(color=color),
        legendgroup=exp_id,
        legendgrouptitle_text=exp_id),
        row=1,
        col=2)

fig.add_shape(
    type='line', line=dict(dash='dash'),
    x0=0, x1=1, y0=0, y1=1,
    row = 1, col = 1
)
fig.add_shape(
    type='line', line=dict(dash='dash'),
    x0=0, x1=1, y0=1, y1=0,
    row = 1, col = 2 
)
fig.update_layout(
    width=900, height=400,
    margin=go.layout.Margin(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    legend=dict(
        yanchor="top",
        y=1.05,
        xanchor="left",
        x=0.97
        ))
fig.update_xaxes(title_text="FPR", constrain='domain', scaleratio = 1, row=1, col=1)
fig.update_yaxes(title_text="TPR (Recall)", constrain='domain', scaleanchor = "x", scaleratio = 1, row=1, col=1)
fig.update_xaxes(title_text="Recall", constrain='domain', scaleanchor = "y", scaleratio = 1, row=1, col=2)
fig.update_yaxes(title_text="Precision", constrain='domain', scaleratio = 1, row=1, col=2)
fig.update_layout(
    title='AUC and AUCPR curves for testing set',
    title_x=0.5,
    margin={'t': 100})
fig.write_html(os.path.join(comparison_path, 'auc_aucpr_testing.html'))

# %%
fig = go.Figure()
auc_scores = []

for exp_id in exp_ids:
    df = get_single_exp_df(exp_id, exp_log, exp_path)
    df_plot = df[(df.epoch == 0) & (df.phase == 'testing')]
    y_true = df_plot.target
    y_score = np.array(df_plot.output.values.tolist())[:, 1]
    color = next(palette)

    df_plot_phase = df_plot
    y_true = df_plot_phase.target
    y_score = np.array(df_plot_phase.output.values.tolist())[:, 1]

    fpr_roc, tpr_roc, thr_roc = roc_curve(y_true, y_score)
    pr_pr, rec_pr, thr_pr = precision_recall_curve(y_true, y_score)

    auc_score = auc(fpr_roc, tpr_roc)
    auc_scores.append(auc_score)
    name_roc = f'AUC={auc_score:.4f}'

    fig.add_trace(go.Bar(
        x = ['AUC'],
        y = [auc_score],
        name = name_roc,
        legendgroup = exp_id,
        legendgrouptitle_text = exp_id
    ))

fig.update_yaxes(title_text="Value")
fig.update_layout(
    barmode='group',
    title=f'AUC bars comparison for {exp_type}',
    title_x=0.5,
    width=1100, height=600)
fig.write_html(os.path.join(comparison_path, 'auc_testing_bars.html'))

# %%
######## F1 and MCC bar plots
palette = cycle(px.colors.qualitative.Plotly)
fig = go.Figure()

thr = 0.5

for exp_id in exp_ids:
    df = get_single_exp_df(exp_id, exp_log, exp_path)
    df_plot = df[(df.epoch == 0) & (df.phase == 'testing')]
    y_true = df_plot.target
    y_score = np.array(df_plot.output.values.tolist())[:, 1]
    y_pred = (y_score > thr)*1
    color = next(palette)
    f1 = f1_score(y_true, y_pred)
    mcc = matthews_corrcoef(y_true, y_pred)

    name_f1 = f'F1={f1:.4f}'
    name_mcc = f'MCC={mcc:.4f}'

    fig.add_trace(go.Bar(
        x=['F1', 'MCC'],
        y=[f1, mcc],
        name = name_f1 + ', ' + name_mcc,
        legendgroup=exp_id,
        legendgrouptitle_text=exp_id,
        marker_color = color
    ))

fig.update_yaxes(title_text="Score")
fig.update_layout(
    barmode='group',
    title='F1 and MCC scores for testing set',
    title_x=0.5,
    width=800, height=500)
fig.write_html(os.path.join(comparison_path, 'f1_mcc_thr.5_testing.html'))

# %%
######## Timings
fig = go.Figure()

for exp_id in exp_ids:
    start = exp_log.loc[exp_id].start_time
    end = exp_log.loc[exp_id].end_time
    start_dt = datetime.strptime(start, '%d/%b/%Y_%H:%M:%S')
    end_dt = datetime.strptime(end, '%d/%b/%Y_%H:%M:%S')
    time = end_dt - start_dt

    fig.add_trace(go.Bar(
        x=[exp_id],
        y=[time.seconds],
        name = str(time) + ' hours'
    ))

fig.update_yaxes(title_text="Seconds")
fig.update_layout(
    barmode='group',
    title='Total timings for the experiments',
    title_x=0.5,
    width=600, height=500)
fig.write_html(os.path.join(comparison_path, 'timings.html'))
