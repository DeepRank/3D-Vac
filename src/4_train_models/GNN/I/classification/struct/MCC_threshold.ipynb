# %%
import h5py
import glob
import os
import sys
from pathlib import Path
import torch
import pandas as pd
import numpy as np
import logging
from deeprankcore.trainer import Trainer
from deeprankcore.dataset import GraphDataset
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from sklearn.metrics import (
    roc_curve,
    precision_recall_curve,
    auc,
    average_precision_score,
    precision_score,
    recall_score,
    accuracy_score,
    f1_score,
    matthews_corrcoef)

# %%
#################### To fill
exp_id = 'exp_100k_final_Increase2_seed55_rmpssm_0'
cluster_dataset =  False # fill in only if the experiment has clusters
project_folder = '/projects/0/einf2380'
protein_class = 'I'
exp_basepath = f'{project_folder}/data/pMHC{protein_class}/trained_models/deeprankcore/experiments/cyulin'
####################
exp_df = pd.read_excel(os.path.join(exp_basepath, 'cyulin_experiments_log.xlsx'), index_col='exp_id')
exp_df.head()
# Out:
#                                                                                          exp_fullname  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...  exp_100k_final_feattrans_Increase1_cl_allele_s...
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0  exp_100k_final_feattrans_Increase1_seed55_rmps...
# exp_100k_final_feattrans_Increase1_cl_peptide2_...  exp_100k_final_feattrans_Increase1_cl_peptide2...
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0  exp_100k_final_feattrans_Increase1_seed44_rmps...
# exp_100k_final_Increase2_seed55_rmpssm_0              exp_100k_final_Increase2_seed55_rmpssm_0_230603
#
#                                                                                              exp_path  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...  /projects/0/einf2380/data/pMHCI/trained_models...
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0  /projects/0/einf2380/data/pMHCI/trained_models...
# exp_100k_final_feattrans_Increase1_cl_peptide2_...  /projects/0/einf2380/data/pMHCI/trained_models...
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0  /projects/0/einf2380/data/pMHCI/trained_models...
# exp_100k_final_Increase2_seed55_rmpssm_0            /projects/0/einf2380/data/pMHCI/trained_models...
#
#                                                               start_time  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...  04/Jun/2023_00:48:35
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0  04/Jun/2023_00:34:14
# exp_100k_final_feattrans_Increase1_cl_peptide2_...  04/Jun/2023_00:37:48
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0  04/Jun/2023_00:28:18
# exp_100k_final_Increase2_seed55_rmpssm_0            03/Jun/2023_13:34:06
#
#                                                                 end_time  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...  04/Jun/2023_05:37:54
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0  04/Jun/2023_05:27:42
# exp_100k_final_feattrans_Increase1_cl_peptide2_...  04/Jun/2023_05:23:14
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0  04/Jun/2023_05:22:43
# exp_100k_final_Increase2_seed55_rmpssm_0            03/Jun/2023_20:29:05
#
#                                                                                       input_data_path  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...  ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0  ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_final_feattrans_Increase1_cl_peptide2_...  ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0  ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_final_Increase2_seed55_rmpssm_0            ['/projects/0/einf2380/data/pMHCI/features_out...
#
#                                                    protein_class target_data  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...             I          BA
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0             I          BA
# exp_100k_final_feattrans_Increase1_cl_peptide2_...             I          BA
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0             I          BA
# exp_100k_final_Increase2_seed55_rmpssm_0                       I          BA
#
#                                                    resolution     task  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...    residue  classif
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0    residue  classif
# exp_100k_final_feattrans_Increase1_cl_peptide2_...    residue  classif
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0    residue  classif
# exp_100k_final_Increase2_seed55_rmpssm_0              residue  classif
#
#                                                    node_features  ...  \
# exp_id                                                            ...
# exp_100k_final_feattrans_Increase1_cl_allele_se...           all  ...
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0           all  ...
# exp_100k_final_feattrans_Increase1_cl_peptide2_...           all  ...
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0           all  ...
# exp_100k_final_Increase2_seed55_rmpssm_0                     all  ...
#
#                                                    testing_f1  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...      0.579
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0      0.757
# exp_100k_final_feattrans_Increase1_cl_peptide2_...      0.692
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0      0.763
# exp_100k_final_Increase2_seed55_rmpssm_0                0.756
#
#                                                    training_accuracy  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...             0.696
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0             0.792
# exp_100k_final_feattrans_Increase1_cl_peptide2_...             0.798
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0             0.805
# exp_100k_final_Increase2_seed55_rmpssm_0                       0.778
#
#                                                    validation_accuracy  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...               0.685
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0               0.765
# exp_100k_final_feattrans_Increase1_cl_peptide2_...               0.769
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0               0.782
# exp_100k_final_Increase2_seed55_rmpssm_0                         0.757
#
#                                                     testing_accuracy  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...             0.629
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0             0.771
# exp_100k_final_feattrans_Increase1_cl_peptide2_...             0.773
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0             0.783
# exp_100k_final_Increase2_seed55_rmpssm_0                       0.771
#
#                                                     training_precision  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...               0.598
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0               0.725
# exp_100k_final_feattrans_Increase1_cl_peptide2_...               0.746
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0               0.774
# exp_100k_final_Increase2_seed55_rmpssm_0                         0.695
#
#                                                     validation_precision  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...                 0.589
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0                 0.690
# exp_100k_final_feattrans_Increase1_cl_peptide2_...                 0.719
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0                 0.757
# exp_100k_final_Increase2_seed55_rmpssm_0                           0.677
#
#                                                     testing_precision  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...              0.543
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0              0.711
# exp_100k_final_feattrans_Increase1_cl_peptide2_...              0.650
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0              0.735
# exp_100k_final_Increase2_seed55_rmpssm_0                        0.711
#
#                                                    training_recall  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...           0.960
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0           0.849
# exp_100k_final_feattrans_Increase1_cl_peptide2_...           0.850
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0           0.787
# exp_100k_final_Increase2_seed55_rmpssm_0                     0.885
#
#                                                     validation_recall  \
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...              0.957
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0              0.847
# exp_100k_final_feattrans_Increase1_cl_peptide2_...              0.818
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0              0.743
# exp_100k_final_Increase2_seed55_rmpssm_0                        0.856
#
#                                                     testing_recall
# exp_id
# exp_100k_final_feattrans_Increase1_cl_allele_se...           0.620
# exp_100k_final_feattrans_Increase1_seed55_rmpssm_0           0.809
# exp_100k_final_feattrans_Increase1_cl_peptide2_...           0.741
# exp_100k_final_feattrans_Increase1_seed44_rmpssm_0           0.795
# exp_100k_final_Increase2_seed55_rmpssm_0                     0.808
#
# [5 rows x 49 columns]

# %%
exp_fullname = exp_df.loc[exp_id].exp_fullname
exp_path = os.path.join(exp_basepath, exp_fullname)
output_path = os.path.join(exp_path, 'output')
img_path = os.path.join(exp_path, 'images')

df_summ = pd.read_hdf(os.path.join(output_path, 'summary_data.hdf5'), key='summary')
output_train = pd.read_hdf(os.path.join(output_path, 'output_exporter.hdf5'), key='training')
output_test = pd.read_hdf(os.path.join(output_path, 'output_exporter.hdf5'), key='testing')
df = pd.concat([output_train, output_test])
df.sort_values(by=['epoch'], inplace = True)
print(df.shape)
# Out:
# (3792611, 6)

# %%
if cluster_dataset:
    df = df.merge(df_summ[['entry', 'cluster']], how='left', on='entry')
    print(df.shape)
    df.head()

# %%
epoch = exp_df.loc[exp_id].saved_epoch
df_plot = df[(df.epoch == epoch) | ((df.epoch == 0) & (df.phase == 'testing'))]
print(df_plot.shape)
y_true = df_plot.target
y_score = np.array(df_plot.output.values.tolist())[:, 1]
# Out:
# (100069, 6)

# %%
d = {'thr': [], 'precision': [], 'recall': [], 'accuracy': [], 'f1': [], 'mcc': [], 'auc': [], 'aucpr': [], 'phase': []}
thr_df = pd.DataFrame(data=d)

for idx, set in enumerate(['training']):
    df_plot_phase = df_plot[(df_plot.phase == set)]
    y_true = df_plot_phase.target
    y_score = np.array(df_plot_phase.output.values.tolist())[:, 1]

    thrs = np.linspace(0,1,100)
    mcc = []
    
    for thr in thrs:
        y_pred = (y_score > thr)*1
        mcc.append(matthews_corrcoef(y_true, y_pred))
    
    fpr_roc, tpr_roc, thr_roc = roc_curve(y_true, y_score)
    auc_score = auc(fpr_roc, tpr_roc)
    aucpr = average_precision_score(y_true, y_score)

    phase_df = pd.DataFrame({'thr': thrs ,'mcc': mcc, 'auc': auc_score, 'aucpr': aucpr, 'phase': set})
    thr_df = pd.concat([thr_df, phase_df], ignore_index=True)

# find max mcc of test set
test_df = thr_df.loc[thr_df.phase == 'training']
test_mcc_idxmax = test_df.mcc.idxmax()
if thr_df.loc[test_mcc_idxmax].mcc > 0:
    sel_thr = thr_df.loc[test_mcc_idxmax].thr
# use max mcc of all data if max of test set is 0 (usually only on small local test experiments)
else:
    mcc_idxmax = thr_df.mcc.idxmax()
    sel_thr = thr_df.loc[mcc_idxmax].thr
    print("WARNING: Maximum mcc of test set is 0. Instead, maximum mcc of all data will be used for determining optimal threshold.\n")

fig_thresh = px.line(
    thr_df,
    x='thr',
    y=[
        'mcc'
    ],
    facet_col='phase',
    category_orders={'phase': [
        "validation"]},
    width=600,
    height=500
)
fig_thresh.add_vline(x=sel_thr, line_width=3, line_dash="dash", line_color="green")
fig_thresh.update_layout(
    title='MCC score vs thresholds (Standardization Applied)',
    title_x=0.5)
fig_thresh.update_yaxes(range=[-0.2, 1.2], scaleanchor="x", scaleratio=1, constrain='domain')
fig_thresh.update_xaxes(range=[0, 1], scaleratio = 1, constrain='domain')
fig_thresh.write_html(os.path.join(img_path, 'thresholds_metrics.html'))


print(f"Maximum MCC score for training appears at threshold: {sel_thr}")
print(f"Maximum MCC score is: {thr_df.loc[test_mcc_idxmax].mcc}")
# Out:
# Maximum MCC score for training appears at threshold: 0.5050505050505051
# Maximum MCC score is: 0.5979369673411115

# %%
d = {'thr': [], 'precision': [], 'recall': [], 'accuracy': [], 'f1': [], 'mcc': [], 'auc': [], 'aucpr': [], 'phase': []}
thr_df = pd.DataFrame(data=d)

for idx, set in enumerate(['validation']):
    df_plot_phase = df_plot[(df_plot.phase == set)]
    y_true = df_plot_phase.target
    y_score = np.array(df_plot_phase.output.values.tolist())[:, 1]

    thrs = np.linspace(0,1,100)
    mcc = []
    
    for thr in thrs:
        y_pred = (y_score > thr)*1
        mcc.append(matthews_corrcoef(y_true, y_pred))
    
    fpr_roc, tpr_roc, thr_roc = roc_curve(y_true, y_score)
    auc_score = auc(fpr_roc, tpr_roc)
    aucpr = average_precision_score(y_true, y_score)

    phase_df = pd.DataFrame({'thr': thrs ,'mcc': mcc, 'auc': auc_score, 'aucpr': aucpr, 'phase': set})
    thr_df = pd.concat([thr_df, phase_df], ignore_index=True)

# find max mcc of test set
test_df = thr_df.loc[thr_df.phase == 'validation']
test_mcc_idxmax = test_df.mcc.idxmax()
if thr_df.loc[test_mcc_idxmax].mcc > 0:
    sel_thr = thr_df.loc[test_mcc_idxmax].thr
# use max mcc of all data if max of test set is 0 (usually only on small local test experiments)
else:
    mcc_idxmax = thr_df.mcc.idxmax()
    sel_thr = thr_df.loc[mcc_idxmax].thr
    print("WARNING: Maximum mcc of test set is 0. Instead, maximum mcc of all data will be used for determining optimal threshold.\n")

fig_thresh = px.line(
    thr_df,
    x='thr',
    y=[
        'mcc'
    ],
    facet_col='phase',
    category_orders={'phase': [
        "validation"]},
    width=600,
    height=500
)
fig_thresh.add_vline(x=sel_thr, line_width=3, line_dash="dash", line_color="green")
fig_thresh.update_layout(
    title='MCC score vs thresholds (Standardization Applied)',
    title_x=0.5)
fig_thresh.update_yaxes(range=[-0.2, 1.2], scaleanchor="x", scaleratio=1, constrain='domain')
fig_thresh.update_xaxes(range=[0, 1], scaleratio = 1, constrain='domain')
fig_thresh.write_html(os.path.join(img_path, 'thresholds_metrics.html'))


print(f"Maximum MCC score for validation appears at threshold: {sel_thr}")
print(f"Maximum MCC score is: {thr_df.loc[test_mcc_idxmax].mcc}")
# Out:
# Maximum MCC score for validation appears at threshold: 0.5555555555555556
# Maximum MCC score is: 0.5597089079789267

# %%
d = {'thr': [], 'precision': [], 'recall': [], 'accuracy': [], 'f1': [], 'mcc': [], 'auc': [], 'aucpr': [], 'phase': []}
thr_df = pd.DataFrame(data=d)

for idx, set in enumerate(['testing']):
    df_plot_phase = df_plot[(df_plot.phase == set)]
    y_true = df_plot_phase.target
    y_score = np.array(df_plot_phase.output.values.tolist())[:, 1]

    thrs = np.linspace(0,1,100)
    mcc = []
    
    for thr in thrs:
        y_pred = (y_score > thr)*1
        mcc.append(matthews_corrcoef(y_true, y_pred))
    
    fpr_roc, tpr_roc, thr_roc = roc_curve(y_true, y_score)
    auc_score = auc(fpr_roc, tpr_roc)
    aucpr = average_precision_score(y_true, y_score)

    phase_df = pd.DataFrame({'thr': thrs ,'mcc': mcc, 'auc': auc_score, 'aucpr': aucpr, 'phase': set})
    thr_df = pd.concat([thr_df, phase_df], ignore_index=True)

# find max mcc of test set
test_df = thr_df.loc[thr_df.phase == 'testing']
test_mcc_idxmax = test_df.mcc.idxmax()
if thr_df.loc[test_mcc_idxmax].mcc > 0:
    sel_thr = thr_df.loc[test_mcc_idxmax].thr
# use max mcc of all data if max of test set is 0 (usually only on small local test experiments)
else:
    mcc_idxmax = thr_df.mcc.idxmax()
    sel_thr = thr_df.loc[mcc_idxmax].thr
    print("WARNING: Maximum mcc of test set is 0. Instead, maximum mcc of all data will be used for determining optimal threshold.\n")

fig_thresh = px.line(
    thr_df,
    x='thr',
    y=[
        'mcc'
    ],
    facet_col='phase',
    category_orders={'phase': [
        "validation"]},
    width=600,
    height=500
)
fig_thresh.add_vline(x=sel_thr, line_width=3, line_dash="dash", line_color="green")
fig_thresh.update_layout(
    title='MCC score vs thresholds (Standardization Applied)',
    title_x=0.5)
fig_thresh.update_yaxes(range=[-0.2, 1.2], scaleanchor="x", scaleratio=1, constrain='domain')
fig_thresh.update_xaxes(range=[0, 1], scaleratio = 1, constrain='domain')
fig_thresh.write_html(os.path.join(img_path, 'thresholds_metrics.html'))


print(f"Maximum MCC score for testing appears at threshold: {sel_thr}")
print(f"Maximum MCC score is: {thr_df.loc[test_mcc_idxmax].mcc}")
# Out:
# Maximum MCC score for testing appears at threshold: 0.3535353535353536
# Maximum MCC score is: 0.5456289628153725
