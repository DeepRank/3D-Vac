# %%
import pandas as pd
from datetime import datetime
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import os
from itertools import cycle
import numpy as np
from sklearn.metrics import (
    roc_curve,
    precision_recall_curve,
    auc,
    average_precision_score,
    f1_score,
    matthews_corrcoef)

# %%
######## Modify here
exp_path = './experiments/'
exp_ids = [
    'exp_100k_std_bs16_0',
    'exp_100k_std_bs16_net2_0']
comparison_id = 'naive_vs_net2'
exp_type = 'Naive GNN vs Net2'
exp_log = pd.read_excel(exp_path + '_experiments_log.xlsx', index_col='exp_id')
exp_log.head()
# Out:
#                                                                                     exp_fullname  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0  exp_100k_dist_res_type_std_bs16_cl_allele_C_0_...
# exp_100k_std_bs16_net2_0                                         exp_100k_std_bs16_net2_0_230421
# exp_692_std_bs16_net2_0                                           exp_692_std_bs16_net2_0_230421
# exp_100k_dist_res_type_std_bs16_cl_peptide_0   exp_100k_dist_res_type_std_bs16_cl_peptide_0_2...
# exp_100k_dist_res_type_std_bs16_0                       exp_100k_dist_res_type_std_bs16_0_230417
#
#                                                                                         exp_path  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0  ./experiments/exp_100k_dist_res_type_std_bs16_...
# exp_100k_std_bs16_net2_0                           ./experiments/exp_100k_std_bs16_net2_0_230421
# exp_692_std_bs16_net2_0                             ./experiments/exp_692_std_bs16_net2_0_230421
# exp_100k_dist_res_type_std_bs16_cl_peptide_0   ./experiments/exp_100k_dist_res_type_std_bs16_...
# exp_100k_dist_res_type_std_bs16_0              ./experiments/exp_100k_dist_res_type_std_bs16_...
#
#                                                          start_time  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0  21/Apr/2023_14:26:44
# exp_100k_std_bs16_net2_0                       21/Apr/2023_17:49:12
# exp_692_std_bs16_net2_0                        21/Apr/2023_15:15:43
# exp_100k_dist_res_type_std_bs16_cl_peptide_0   17/Apr/2023_17:00:02
# exp_100k_dist_res_type_std_bs16_0              17/Apr/2023_16:56:38
#
#                                                            end_time  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0  21/Apr/2023_22:41:06
# exp_100k_std_bs16_net2_0                       21/Apr/2023_22:04:17
# exp_692_std_bs16_net2_0                        21/Apr/2023_15:16:16
# exp_100k_dist_res_type_std_bs16_cl_peptide_0   17/Apr/2023_22:49:06
# exp_100k_dist_res_type_std_bs16_0              17/Apr/2023_22:39:50
#
#                                                                                  input_data_path  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0  ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_std_bs16_net2_0                       ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_692_std_bs16_net2_0                        ['/home/ccrocion/snellius_data_sample/data/pMH...
# exp_100k_dist_res_type_std_bs16_cl_peptide_0   ['/projects/0/einf2380/data/pMHCI/features_out...
# exp_100k_dist_res_type_std_bs16_0              ['/projects/0/einf2380/data/pMHCI/features_out...
#
#                                               protein_class target_data  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0             I          BA
# exp_100k_std_bs16_net2_0                                  I          BA
# exp_692_std_bs16_net2_0                                   I          BA
# exp_100k_dist_res_type_std_bs16_cl_peptide_0              I          BA
# exp_100k_dist_res_type_std_bs16_0                         I          BA
#
#                                               resolution     task  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0    residue  classif
# exp_100k_std_bs16_net2_0                         residue  classif
# exp_692_std_bs16_net2_0                          residue  classif
# exp_100k_dist_res_type_std_bs16_cl_peptide_0     residue  classif
# exp_100k_dist_res_type_std_bs16_0                residue  classif
#
#                                               node_features  ... testing_f1  \
# exp_id                                                       ...
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0           all  ...      0.601
# exp_100k_std_bs16_net2_0                                all  ...      0.755
# exp_692_std_bs16_net2_0                                 all  ...      0.615
# exp_100k_dist_res_type_std_bs16_cl_peptide_0            all  ...      0.696
# exp_100k_dist_res_type_std_bs16_0                       all  ...      0.727
#
#                                               training_accuracy  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0             0.704
# exp_100k_std_bs16_net2_0                                  0.815
# exp_692_std_bs16_net2_0                                   0.517
# exp_100k_dist_res_type_std_bs16_cl_peptide_0              0.751
# exp_100k_dist_res_type_std_bs16_0                         0.739
#
#                                               validation_accuracy  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0               0.702
# exp_100k_std_bs16_net2_0                                    0.785
# exp_692_std_bs16_net2_0                                     0.504
# exp_100k_dist_res_type_std_bs16_cl_peptide_0                0.752
# exp_100k_dist_res_type_std_bs16_0                           0.741
#
#                                                testing_accuracy  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0             0.535
# exp_100k_std_bs16_net2_0                                  0.788
# exp_692_std_bs16_net2_0                                   0.571
# exp_100k_dist_res_type_std_bs16_cl_peptide_0              0.711
# exp_100k_dist_res_type_std_bs16_0                         0.740
#
#                                                training_precision  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0               0.609
# exp_100k_std_bs16_net2_0                                    0.838
# exp_692_std_bs16_net2_0                                     0.488
# exp_100k_dist_res_type_std_bs16_cl_peptide_0                0.700
# exp_100k_dist_res_type_std_bs16_0                           0.673
#
#                                                validation_precision  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0                 0.608
# exp_100k_std_bs16_net2_0                                      0.816
# exp_692_std_bs16_net2_0                                       0.478
# exp_100k_dist_res_type_std_bs16_cl_peptide_0                  0.695
# exp_100k_dist_res_type_std_bs16_0                             0.671
#
#                                                testing_precision  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0              0.774
# exp_100k_std_bs16_net2_0                                   0.769
# exp_692_std_bs16_net2_0                                    0.522
# exp_100k_dist_res_type_std_bs16_cl_peptide_0               0.640
# exp_100k_dist_res_type_std_bs16_0                          0.676
#
#                                               training_recall  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0           0.903
# exp_100k_std_bs16_net2_0                                0.719
# exp_692_std_bs16_net2_0                                 0.961
# exp_100k_dist_res_type_std_bs16_cl_peptide_0            0.761
# exp_100k_dist_res_type_std_bs16_0                       0.791
#
#                                                validation_recall  \
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0              0.894
# exp_100k_std_bs16_net2_0                                   0.659
# exp_692_std_bs16_net2_0                                    0.965
# exp_100k_dist_res_type_std_bs16_cl_peptide_0               0.779
# exp_100k_dist_res_type_std_bs16_0                          0.804
#
#                                                testing_recall
# exp_id
# exp_100k_dist_res_type_std_bs16_cl_allele_C_0           0.491
# exp_100k_std_bs16_net2_0                                0.743
# exp_692_std_bs16_net2_0                                 0.750
# exp_100k_dist_res_type_std_bs16_cl_peptide_0            0.764
# exp_100k_dist_res_type_std_bs16_0                       0.785
#
# [5 rows x 49 columns]

# %%
######## Definitions used in the plotting
comparisons_path = os.path.join(exp_path, 'comparisons')
comparison_path = os.path.join(comparisons_path, comparison_id)

if not os.path.exists(comparisons_path):
    os.makedirs(comparisons_path)

if not os.path.exists(comparison_path):
    os.makedirs(comparison_path)
else:
    print(f'Folder comparisons/{comparison_id}/ already exists! \
          \nChange comparison_id if you want to save plots for a different comparison.')

def get_single_exp_df(exp_id, exp_log, exp_path):
    exp_fullname = exp_log.loc[exp_id].exp_fullname
    exp_path = os.path.join(exp_path, exp_fullname)
    output_path = os.path.join(exp_path, 'output')
    output_train = pd.read_hdf(os.path.join(output_path, 'output_exporter.hdf5'), key='training')
    output_test = pd.read_hdf(os.path.join(output_path, 'output_exporter.hdf5'), key='testing')
    df = pd.concat([output_train, output_test])
    df.sort_values(by=['epoch'], inplace = True)
    return df
# Out:
# Folder comparisons/naive_vs_net2/ already exists!
# Change comparison_id if you want to save plots for a different comparison.

# %%
######## Losses curves
palette = cycle(px.colors.qualitative.Plotly)
fig = go.Figure()

count=0
for exp_id in exp_ids:
    df = get_single_exp_df(exp_id, exp_log, exp_path)
    df_grouped = df.groupby(['phase', 'epoch']).mean().reset_index()[['phase', 'epoch', 'loss']]
    color = next(palette)
    df_train_plot = df_grouped[(df_grouped.phase =='training') & (df_grouped.epoch > 0)]
    df_valid_plot = df_grouped[(df_grouped.phase =='validation') & (df_grouped.epoch > 0)]

    fig.add_trace(go.Scatter(
        x=df_train_plot.epoch,
        y=df_train_plot.loss,
        mode = 'lines+markers',
        line=dict(color=color),
        name='training',
        legendgroup=exp_show_name[count],
        legendgrouptitle_text=exp_show_name[count]))
    fig.add_trace(go.Scatter(
        x=df_valid_plot.epoch,
        y=df_valid_plot.loss,
        mode = 'lines+markers',
        line=dict(color=color, dash='dot'),
        name='validation',
        legendgroup=exp_show_name[count],
        legendgrouptitle_text=exp_show_name[count]))
    
    epoch = exp_log.loc[exp_id].saved_epoch
    fig.add_trace(go.Scatter(
        x=[epoch],
        y=[exp_log.loc[exp_id].training_loss],
        mode = 'markers',
        marker_symbol = 'star',
        marker_color = 'firebrick',
        marker_size = 15,
        name = f'epoch {epoch}',
        legendgroup=exp_id,
        showlegend = False))
    count+=1

fig.update_layout(
    xaxis_title='Epoch #',
    yaxis_title='Loss',
    width=1000, height=600,
    title='Learning Curves for Batch Normalization Experiment (With all BN Methods)',
    title_x=0.5,
    margin=go.layout.Margin(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4),
    legend=dict(
        yanchor="top",
        xanchor="right",
        x=0.99
        )
)
fig.write_html(os.path.join(comparison_path, 'losses.html'))
# Out:
# /scratch-local/ccrocion/ipykernel_2594438/3607644268.py:7: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#
# /scratch-local/ccrocion/ipykernel_2594438/3607644268.py:7: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
######## AUC and AUCPR curves
palette = cycle(px.colors.qualitative.Plotly)
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles = ['ROC Curves (AUC)', 'PR Curves (AUCPR)'],
    horizontal_spacing = 0.05)

count=0
for exp_id in exp_ids:
    df = get_single_exp_df(exp_id, exp_log, exp_path)
    df_plot = df[(df.epoch == 0) & (df.phase == 'testing')]
    y_true = df_plot.target
    y_score = np.array(df_plot.output.values.tolist())[:, 1]
    color = next(palette)

    df_plot_phase = df_plot
    y_true = df_plot_phase.target
    y_score = np.array(df_plot_phase.output.values.tolist())[:, 1]

    fpr_roc, tpr_roc, thr_roc = roc_curve(y_true, y_score)
    pr_pr, rec_pr, thr_pr = precision_recall_curve(y_true, y_score)

    name_roc = f'AUC={auc(fpr_roc, tpr_roc):.4f}'
    name_pr = f'AUCPR={average_precision_score(y_true, y_score):.4f}'

    fig.add_trace(go.Scatter(
        x=fpr_roc,
        y=tpr_roc,
        name=name_roc,
        line=dict(color=color),
        legendgroup=exp_show_name[count],
        legendgrouptitle_text=exp_show_name[count]),
        row=1,
        col=1)
    fig.add_trace(go.Scatter(
        x=rec_pr,
        y=pr_pr,
        name=name_pr,
        line=dict(color=color),
        legendgroup=exp_show_name[count],
        legendgrouptitle_text=exp_show_name[count]),
        row=1,
        col=2)
    count+=1
fig.add_shape(
    type='line', line=dict(dash='dash'),
    x0=0, x1=1, y0=0, y1=1,
    row = 1, col = 1
)
fig.add_shape(
    type='line', line=dict(dash='dash'),
    x0=0, x1=1, y0=1, y1=0,
    row = 1, col = 2 
)
fig.update_layout(
    width=900, height=400,
    margin=go.layout.Margin(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    legend=dict(
        yanchor="top",
        y=1.05,
        xanchor="left",
        x=0.97
        ))
fig.update_xaxes(title_text="FPR", constrain='domain', scaleratio = 1, row=1, col=1)
fig.update_yaxes(title_text="TPR (Recall)", constrain='domain', scaleanchor = "x", scaleratio = 1, row=1, col=1)
fig.update_xaxes(title_text="Recall", constrain='domain', scaleanchor = "y", scaleratio = 1, row=1, col=2)
fig.update_yaxes(title_text="Precision", constrain='domain', scaleratio = 1, row=1, col=2)
fig.update_layout(
    title='AUC and AUCPR curves for testing set',
    title_x=0.5,
    margin={'t': 100})
fig.write_html(os.path.join(comparison_path, 'auc_aucpr_testing.html'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 13
#      11 df_plot = df[(df.epoch == 0) & (df.phase == 'testing')]
#      12 y_true = df_plot.target
# ---> 13 y_score = np.array(df_plot.output.values.tolist())[:, 1]
#      14 color = next(palette)
#      16 df_plot_phase = df_plot
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
colors=px.colors.qualitative.Plotly
#print(colors[1])

# %%
#AUC score bar comparison
fig = go.Figure()
auc_scores = []

count=0
for exp_id in exp_ids:
    df = get_single_exp_df(exp_id, exp_log, exp_path)
    df_plot = df[(df.epoch == 0) & (df.phase == 'testing')]
    y_true = df_plot.target
    y_score = np.array(df_plot.output.values.tolist())[:, 1]
    color = next(palette)

    df_plot_phase = df_plot
    y_true = df_plot_phase.target
    y_score = np.array(df_plot_phase.output.values.tolist())[:, 1]

    fpr_roc, tpr_roc, thr_roc = roc_curve(y_true, y_score)
    pr_pr, rec_pr, thr_pr = precision_recall_curve(y_true, y_score)

    auc_score = auc(fpr_roc, tpr_roc)
    auc_scores.append(auc_score)
    name_roc = f'AUC={auc_score:.4f}'

    fig.add_trace(go.Bar(
        x = ['AUC'],
        y = [auc_score],
        name = name_roc,
        legendgroup = exp_show_name[count],
        legendgrouptitle_text = exp_show_name[count]
    ))
    count+=1
    

fig.update_yaxes(title_text="Value")
fig.update_layout(
    barmode='group',
    title=f'AUC Scores for Batch Normalization Experiment (With all BN Methods)', #modify
    title_x=0.5,
    width=700, height=600,
    yaxis_range=[0.4,0.9])
fig.write_html(os.path.join(comparison_path, 'auc_testing_bars.html'))

# %%
######## F1 and MCC bar plots
palette = cycle(px.colors.qualitative.Plotly)
fig = go.Figure()

thr = [0.47,0.52,0.43,0.35,0.58,0.56] #modify, max mcc threshold

count=0
for exp_id in exp_ids:
    df = get_single_exp_df(exp_id, exp_log, exp_path)
    df_plot = df[(df.epoch == 0) & (df.phase == 'testing')]
    y_true = df_plot.target
    y_score = np.array(df_plot.output.values.tolist())[:, 1]
    y_pred = (y_score > thr[count])*1
    color = next(palette)
    mcc = matthews_corrcoef(y_true, y_pred)

    name_mcc = f'MCC={mcc:.4f}'

    fig.add_trace(go.Bar(
        x=['MCC'],
        y=[mcc],
        name = name_mcc,
        legendgroup=exp_show_name[count],
        legendgrouptitle_text=exp_show_name[count],
        marker_color = color
    ))
    count+=1

fig.update_yaxes(title_text="Score")
fig.update_layout(
    barmode='group',
    title='MCC Scores for Data Standardization Experiment', #Modify
    title_x=0.5,
    width=1000, height=500,
    yaxis_range=[0.5,0.7])
fig.write_html(os.path.join(comparison_path, 'mcc_thr.5_testing.html'))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 12
#      10 df_plot = df[(df.epoch == 0) & (df.phase == 'testing')]
#      11 y_true = df_plot.target
# ---> 12 y_score = np.array(df_plot.output.values.tolist())[:, 1]
#      13 y_pred = (y_score > thr[count])*1
#      14 color = next(palette)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
######## Timings
fig = go.Figure()

count=0
for exp_id in exp_ids:
    start = exp_log.loc[exp_id].start_time
    end = exp_log.loc[exp_id].end_time
    start_dt = datetime.strptime(start, '%d/%b/%Y_%H:%M:%S')
    end_dt = datetime.strptime(end, '%d/%b/%Y_%H:%M:%S')
    time = end_dt - start_dt

    fig.add_trace(go.Bar(
        x=[exp_show_name[count]],
        y=[time.seconds],
        name = str(time) + ' hours'
    ))
    count+=1

fig.update_yaxes(title_text="Seconds")
fig.update_layout(
    barmode='group',
    title='Total timings for the experiments',
    title_x=0.5,
    width=600, height=500)
fig.write_html(os.path.join(comparison_path, 'timings.html'))

# %%
print()
